# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhu2507/VRSU/blob/main/VRSU_8_RealObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00
# ...

# %%
# Install library (run once in Colab)
# !pip install ultralytics

# Import libraries
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load pretrained YOLOv8 Nano model
model = YOLO('yolov8n.pt')

# Run detection on image
results = model('/content/sample_data/street.jpg', conf=0.5)

# Process detection results
for result in results:
    boxes = result.boxes

    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0].tolist()
        conf = box.conf[0].item()
        cls_id = int(box.cls[0].item())
        cls_name = model.names[cls_id]

        print(f'{cls_name}: {conf:.2f} at [{x1:.0f}, {y1:.0f}, {x2:.0f}, {y2:.0f}]')

# Show image with bounding boxes
annotated = results[0].plot()
cv2_imshow(annotated)
# Out:
# ...
#
# image 1/1 /content/sample_data/street.jpg: 448x640 3 persons, 4 motorcycles, 277.4ms
# Speed: 12.6ms preprocess, 277.4ms inference, 38.4ms postprocess per image at shape (1, 3, 448, 640)
# person: 0.89 at [21, 23, 174, 302]
# motorcycle: 0.84 at [332, 136, 483, 369]
# person: 0.82 at [335, 45, 478, 331]
# motorcycle: 0.78 at [18, 129, 170, 364]
# motorcycle: 0.71 at [466, 114, 538, 231]
# person: 0.62 at [195, 50, 355, 364]
# motorcycle: 0.62 at [163, 142, 356, 368]
# <PIL.Image.Image image mode=RGB size=555x372>
